# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusMartini/Python/blob/main/Test_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
uri = "https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula6.2/ratings.csv"

movies = pd.read_csv(uri)
notes = movies["rating"].round(1)
notes.value_counts().plot.pie()

# %%
import matplotlib.pyplot as plt

sns.countplot(notes)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
